# %%
# !tshark -n -r redhat_passguessing.pcap -T fields -Eheader=y -e frame.number -e frame.len > frame.len

# %%
import pandas as pd

# %%
df=pd.read_table("frame.len")

# %%
df
# Out:
#        frame.number  frame.len
# 0                 1         76
# 1                 2         54
# 2                 3         64
# 3                 4         54
# 4                 5         62
# 5                 6         62
# 6                 7         54
# 7                 8         74
# 8                 9         66
# 9                10         60
# 10               11         88
# 11               12         66
# 12               13         60
# 13               14         76
# 14               15         54
# 15               16         64
# 16               17         54
# 17               18         62
# 18               19         62
# 19               20         54
# 20               21         74
# 21               22         66
# 22               23         60
# 23               24         88
# 24               25         65
# 25               26         60
# 26               27         76
# 27               28         54
# 28               29         64
# ...

# %%
df["frame.len"].describe()
# Out:
# count    18799.000000
# mean        65.752221
# std         24.349490
# min         42.000000
# 25%         60.000000
# 50%         62.000000
# 75%         70.000000
# max        590.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figsize(10,6)

# %%
df["frame.len"].plot(style=".", alpha=0.2)
title("Frame length Redhat-Passguessing")
ylabel("bytes")
xlabel("frame number")
